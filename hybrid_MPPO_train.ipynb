# %% [markdown]
# # Hybrid RL-Solver Training
#
# Agent places first 5 pieces, solver checks if remaining 3 pieces can complete puzzle.
#
# Rationale: train an early-/mid-game solver. Hopefully agent can learn to put the board in a winnable state, without having to worry about the end game.

# %%
import random

import numpy as np
from sb3_contrib import MaskablePPO
from stable_baselines3.common.vec_env import SubprocVecEnv

# %%
from torch.distributions import Distribution

from training_utils import GradNormCallback, TimerCallback, make_hybrid_env

Distribution.set_default_validate_args(False)

# %% [markdown]
# # Training
#
# Here we go with the strategy of training on one board many times and then switching

# %%
total_timesteps = 1_000_000
checkpoint_interval = 100_000
board_switch_interval = 500_000

# %%
# Generate board pool
n_boards = 100
board_configs = [(random.randint(1, 12), random.randint(1, 30)) for _ in range(n_boards)]

# Select initial boards
selected_boards = random.sample(board_configs, 8)
env = SubprocVecEnv(
    [
        lambda mo=mo, day=day: make_hybrid_env(mo, day, agent_pieces=5, mask_islands=True)
        for mo, day in selected_boards
    ]
)

model = MaskablePPO(
    "MlpPolicy",
    env,
    tensorboard_log="./hybrid_ppo_logs_1/",
    verbose=1,
    batch_size=1000,
    n_steps=2048 * 2,
    ent_coef=0.15,
)

for i in range(0, total_timesteps, checkpoint_interval):
    reset = i == 0
    remaining_steps = min(checkpoint_interval, total_timesteps - i)

    # Switch boards periodically
    if i % board_switch_interval == 0:
        selected_boards = random.sample(board_configs, 8)
        env = SubprocVecEnv(
            [
                lambda mo=mo, day=day: make_hybrid_env(mo, day, agent_pieces=5, mask_islands=True)
                for mo, day in selected_boards
            ]
        )
        model.set_env(env)
        print(f"Switching to boards: {selected_boards}")

    model.learn(
        total_timesteps=remaining_steps,
        reset_num_timesteps=reset,
        callback=[TimerCallback(), GradNormCallback()],
    )

    # if i > 0 and i % 500_000 == 0:
    #    model.save(f"hybrid_model_v1_{i}")

model.save("hybrid_model_v1")
# Out:
# Using cpu device
# Switching to boards: [(9, 8), (6, 21), (8, 25), (8, 2), (11, 18), (6, 5), (5, 12), (9, 7)]
# Logging to ./hybrid_ppo_logs_1/PPO_3
# Step 1000, 5s elapsed, 457s remaining
# Step 2000, 9s elapsed, 431s remaining
# Step 3000, 13s elapsed, 430s remaining
# Step 4000, 18s elapsed, 421s remaining
# Step 5000, 22s elapsed, 415s remaining
# Step 6000, 26s elapsed, 407s remaining
# Step 7000, 30s elapsed, 402s remaining
# Step 8000, 34s elapsed, 396s remaining
# Step 9000, 39s elapsed, 392s remaining
# Step 10000, 43s elapsed, 385s remaining
# Step 11000, 47s elapsed, 380s remaining
# Step 12000, 51s elapsed, 376s remaining
# Step 13000, 56s elapsed, 372s remaining
# Step 14000, 60s elapsed, 368s remaining
# Step 15000, 64s elapsed, 364s remaining
# Step 16000, 68s elapsed, 359s remaining
# Step 17000, 73s elapsed, 356s remaining
# Step 18000, 77s elapsed, 352s remaining
# Step 19000, 82s elapsed, 348s remaining
# Step 20000, 86s elapsed, 344s remaining
# Step 21000, 90s elapsed, 340s remaining
# Step 22000, 95s elapsed, 337s remaining
# Step 23000, 99s elapsed, 333s remaining
# Step 24000, 104s elapsed, 329s remaining
# Step 25000, 108s elapsed, 325s remaining
# Step 26000, 113s elapsed, 321s remaining
# Step 27000, 117s elapsed, 318s remaining
# Step 28000, 122s elapsed, 315s remaining
# Step 29000, 127s elapsed, 310s remaining
# Step 30000, 131s elapsed, 306s remaining
# Step 31000, 135s elapsed, 301s remaining
# Step 32000, 140s elapsed, 297s remaining
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.64     |
# |    ep_rew_mean     | 0.0364   |
# | time/              |          |
# |    fps             | 229      |
# |    iterations      | 1        |
# |    time_elapsed    | 143      |
# |    total_timesteps | 32768    |
# | train/             |          |
# |    grad_norm       | 0        |
# ---------------------------------
# Step 33000, 155s elapsed, 314s remaining
# Step 34000, 159s elapsed, 309s remaining
# Step 35000, 163s elapsed, 303s remaining
# Step 36000, 167s elapsed, 298s remaining
# Step 37000, 172s elapsed, 293s remaining
# Step 38000, 176s elapsed, 287s remaining
# Step 39000, 180s elapsed, 282s remaining
# Step 40000, 185s elapsed, 277s remaining
# Step 41000, 189s elapsed, 272s remaining
# Step 42000, 193s elapsed, 267s remaining
# Step 43000, 197s elapsed, 262s remaining
# Step 44000, 201s elapsed, 256s remaining
# Step 45000, 206s elapsed, 251s remaining
# Step 46000, 210s elapsed, 246s remaining
# Step 47000, 214s elapsed, 242s remaining
# Step 48000, 218s elapsed, 237s remaining
# Step 49000, 223s elapsed, 232s remaining
# Step 50000, 227s elapsed, 227s remaining
# Step 51000, 231s elapsed, 222s remaining
# Step 52000, 236s elapsed, 218s remaining
# Step 53000, 241s elapsed, 213s remaining
# Step 54000, 245s elapsed, 209s remaining
# Step 55000, 250s elapsed, 204s remaining
# Step 56000, 254s elapsed, 200s remaining
# Step 57000, 259s elapsed, 195s remaining
# Step 58000, 263s elapsed, 191s remaining
# Step 59000, 268s elapsed, 186s remaining
# Step 60000, 272s elapsed, 181s remaining
# Step 61000, 276s elapsed, 177s remaining
# Step 62000, 281s elapsed, 172s remaining
# Step 63000, 285s elapsed, 167s remaining
# Step 64000, 290s elapsed, 163s remaining
# Step 65000, 294s elapsed, 158s remaining
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.62        |
# |    ep_rew_mean          | 0.0462      |
# | time/                   |             |
# |    fps                  | 221         |
# |    iterations           | 2           |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011521379 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.75       |
# |    explained_variance   | -1.86       |
# |    grad_norm            | 0.164       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.576      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0441     |
# |    value_loss           | 0.114       |
# -----------------------------------------
# Step 66000, 308s elapsed, 159s remaining
# Step 67000, 313s elapsed, 154s remaining
# Step 68000, 317s elapsed, 149s remaining
# Step 69000, 321s elapsed, 144s remaining
# Step 70000, 326s elapsed, 140s remaining
# Step 71000, 330s elapsed, 135s remaining
# Step 72000, 334s elapsed, 130s remaining
# Step 73000, 338s elapsed, 125s remaining
# Step 74000, 343s elapsed, 120s remaining
# Step 75000, 347s elapsed, 116s remaining
# Step 76000, 351s elapsed, 111s remaining
# Step 77000, 356s elapsed, 106s remaining
# Step 78000, 360s elapsed, 102s remaining
# Step 79000, 364s elapsed, 97s remaining
# Step 80000, 369s elapsed, 92s remaining
# Step 81000, 373s elapsed, 88s remaining
# Step 82000, 377s elapsed, 83s remaining
# Step 83000, 382s elapsed, 78s remaining
# Step 84000, 386s elapsed, 74s remaining
# Step 85000, 390s elapsed, 69s remaining
# Step 86000, 395s elapsed, 64s remaining
# Step 87000, 399s elapsed, 60s remaining
# Step 88000, 404s elapsed, 55s remaining
# Step 89000, 408s elapsed, 50s remaining
# Step 90000, 412s elapsed, 46s remaining
# Step 91000, 417s elapsed, 41s remaining
# Step 92000, 422s elapsed, 37s remaining
# Step 93000, 426s elapsed, 32s remaining
# Step 94000, 431s elapsed, 27s remaining
# Step 95000, 435s elapsed, 23s remaining
# Step 96000, 440s elapsed, 18s remaining
# Step 97000, 444s elapsed, 14s remaining
# Step 98000, 448s elapsed, 9s remaining
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.66        |
# |    ep_rew_mean          | 0.0366      |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 3           |
# |    time_elapsed         | 449         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010890413 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.75       |
# |    explained_variance   | -1.71       |
# |    grad_norm            | 0.16        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.63       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0451     |
# |    value_loss           | 0.0175      |
# -----------------------------------------
# Step 99000, 464s elapsed, 5s remaining
# Step 100000, 468s elapsed, 0s remaining
# Step 101000, 472s elapsed, -5s remaining
# Step 102000, 476s elapsed, -9s remaining
# Step 103000, 481s elapsed, -14s remaining
# Step 104000, 485s elapsed, -19s remaining
# Step 105000, 489s elapsed, -23s remaining
# Step 106000, 493s elapsed, -28s remaining
# Step 107000, 498s elapsed, -33s remaining
# Step 108000, 502s elapsed, -37s remaining
# Step 109000, 506s elapsed, -42s remaining
# Step 110000, 510s elapsed, -46s remaining
# Step 111000, 514s elapsed, -51s remaining
# Step 112000, 518s elapsed, -56s remaining
# Step 113000, 523s elapsed, -60s remaining
# Step 114000, 527s elapsed, -65s remaining
# Step 115000, 531s elapsed, -69s remaining
# Step 116000, 535s elapsed, -74s remaining
# Step 117000, 540s elapsed, -78s remaining
# Step 118000, 544s elapsed, -83s remaining
# Step 119000, 548s elapsed, -88s remaining
# Step 120000, 552s elapsed, -92s remaining
# Step 121000, 557s elapsed, -97s remaining
# Step 122000, 561s elapsed, -101s remaining
# Step 123000, 565s elapsed, -106s remaining
# Step 124000, 570s elapsed, -110s remaining
# Step 125000, 574s elapsed, -115s remaining
# Step 126000, 578s elapsed, -119s remaining
# Step 127000, 582s elapsed, -124s remaining
# Step 128000, 587s elapsed, -128s remaining
# Step 129000, 591s elapsed, -133s remaining
# Step 130000, 595s elapsed, -137s remaining
# Step 131000, 599s elapsed, -142s remaining
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.62       |
# |    ep_rew_mean          | 0.0362     |
# | time/                   |            |
# |    fps                  | 218        |
# |    iterations           | 4          |
# |    time_elapsed         | 599        |
# |    total_timesteps      | 131072     |
# | train/                  |            |
# |    approx_kl            | 0.01039673 |
# |    clip_fraction        | 0.101      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.73      |
# |    explained_variance   | -1.7       |
# |    grad_norm            | 0.153      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.637     |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0415    |
# |    value_loss           | 0.00735    |
# ----------------------------------------
# Logging to ./hybrid_ppo_logs_1/PPO_3
# Step 132000, 4s elapsed, 3s remaining
# Step 133000, 8s elapsed, 6s remaining
# Step 134000, 12s elapsed, 9s remaining
# Step 135000, 17s elapsed, 12s remaining
# Step 136000, 21s elapsed, 15s remaining
# Step 137000, 25s elapsed, 17s remaining
# Step 138000, 30s elapsed, 20s remaining
# Step 139000, 34s elapsed, 22s remaining
# Step 140000, 38s elapsed, 25s remaining
# Step 141000, 42s elapsed, 27s remaining
# Step 142000, 46s elapsed, 29s remaining
# Step 143000, 51s elapsed, 31s remaining
# Step 144000, 55s elapsed, 33s remaining
# Step 145000, 59s elapsed, 35s remaining
# Step 146000, 63s elapsed, 37s remaining
# Step 147000, 67s elapsed, 39s remaining
# Step 148000, 72s elapsed, 40s remaining
# Step 149000, 76s elapsed, 42s remaining
# Step 150000, 80s elapsed, 43s remaining
# Step 151000, 84s elapsed, 45s remaining
# Step 152000, 89s elapsed, 46s remaining
# Step 153000, 93s elapsed, 47s remaining
# Step 154000, 97s elapsed, 49s remaining
# Step 155000, 102s elapsed, 50s remaining
# Step 156000, 106s elapsed, 51s remaining
# Step 157000, 110s elapsed, 52s remaining
# Step 158000, 114s elapsed, 53s remaining
# Step 159000, 118s elapsed, 54s remaining
# Step 160000, 123s elapsed, 54s remaining
# Step 161000, 127s elapsed, 55s remaining
# Step 162000, 131s elapsed, 56s remaining
# Step 163000, 135s elapsed, 56s remaining
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.53     |
# |    ep_rew_mean     | 0.0353   |
# | time/              |          |
# |    fps             | 236      |
# |    iterations      | 1        |
# |    time_elapsed    | 138      |
# |    total_timesteps | 163840   |
# | train/             |          |
# |    grad_norm       | 0.158    |
# ---------------------------------
# Step 164000, 149s elapsed, 61s remaining
# Step 165000, 153s elapsed, 61s remaining
# Step 166000, 157s elapsed, 62s remaining
# Step 167000, 161s elapsed, 62s remaining
# Step 168000, 166s elapsed, 62s remaining
# Step 169000, 170s elapsed, 62s remaining
# Step 170000, 174s elapsed, 63s remaining
# Step 171000, 179s elapsed, 63s remaining
# Step 172000, 183s elapsed, 63s remaining
# Step 173000, 187s elapsed, 63s remaining
# Step 174000, 191s elapsed, 63s remaining
# Step 175000, 195s elapsed, 63s remaining
# Step 176000, 200s elapsed, 63s remaining
# Step 177000, 204s elapsed, 62s remaining
# Step 178000, 209s elapsed, 62s remaining
# Step 179000, 213s elapsed, 62s remaining
# Step 180000, 218s elapsed, 62s remaining
# Step 181000, 222s elapsed, 62s remaining
# Step 182000, 227s elapsed, 61s remaining
# Step 183000, 231s elapsed, 61s remaining
# Step 184000, 235s elapsed, 60s remaining
# Step 185000, 239s elapsed, 60s remaining
# Step 186000, 244s elapsed, 59s remaining
# Step 187000, 248s elapsed, 59s remaining
# Step 188000, 253s elapsed, 58s remaining
# Step 189000, 257s elapsed, 57s remaining
# Step 190000, 261s elapsed, 56s remaining
# Step 191000, 265s elapsed, 56s remaining
# Step 192000, 270s elapsed, 55s remaining
# Step 193000, 274s elapsed, 54s remaining
# Step 194000, 278s elapsed, 53s remaining
# Step 195000, 283s elapsed, 52s remaining
# Step 196000, 287s elapsed, 51s remaining
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.61        |
# |    ep_rew_mean          | 0.0361      |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 2           |
# |    time_elapsed         | 289         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.010523196 |
# |    clip_fraction        | 0.0997      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.72       |
# |    explained_variance   | -1.08       |
# |    grad_norm            | 0.125       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.613      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0418     |
# |    value_loss           | 0.00231     |
# -----------------------------------------
# Step 197000, 304s elapsed, 53s remaining
# Step 198000, 309s elapsed, 52s remaining
# Step 199000, 313s elapsed, 50s remaining
# Step 200000, 319s elapsed, 50s remaining
# Step 201000, 323s elapsed, 48s remaining
# Step 202000, 327s elapsed, 47s remaining
# Step 203000, 332s elapsed, 46s remaining
# Step 204000, 336s elapsed, 45s remaining
# Step 205000, 340s elapsed, 43s remaining
# Step 206000, 344s elapsed, 42s remaining
# Step 207000, 349s elapsed, 41s remaining
# Step 208000, 353s elapsed, 39s remaining
# Step 209000, 357s elapsed, 38s remaining
# Step 210000, 361s elapsed, 36s remaining
# Step 211000, 366s elapsed, 35s remaining
# Step 212000, 370s elapsed, 33s remaining
# Step 213000, 374s elapsed, 32s remaining
# Step 214000, 390s elapsed, 31s remaining
# Step 215000, 399s elapsed, 30s remaining
# Step 216000, 403s elapsed, 28s remaining
# Step 217000, 408s elapsed, 26s remaining
# Step 218000, 412s elapsed, 25s remaining
# Step 219000, 416s elapsed, 23s remaining
# Step 220000, 420s elapsed, 21s remaining
# Step 221000, 425s elapsed, 19s remaining
# Step 222000, 429s elapsed, 18s remaining
# Step 223000, 433s elapsed, 16s remaining
# Step 224000, 438s elapsed, 14s remaining
# Step 225000, 442s elapsed, 12s remaining
# Step 226000, 446s elapsed, 10s remaining
# Step 227000, 451s elapsed, 8s remaining
# Step 228000, 455s elapsed, 6s remaining
# Step 229000, 459s elapsed, 4s remaining
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.5          |
# |    ep_rew_mean          | 0.035        |
# | time/                   |              |
# |    fps                  | 213          |
# |    iterations           | 3            |
# |    time_elapsed         | 460          |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0103573045 |
# |    clip_fraction        | 0.0933       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.72        |
# |    explained_variance   | -0.708       |
# |    grad_norm            | 0.165        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.629       |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0394      |
# |    value_loss           | 0.00159      |
# ------------------------------------------
# Step 230000, 474s elapsed, 2s remaining
# Step 231000, 478s elapsed, 0s remaining
# Step 232000, 483s elapsed, -2s remaining
# Step 233000, 487s elapsed, -4s remaining
# Step 234000, 492s elapsed, -6s remaining
# Step 235000, 496s elapsed, -8s remaining
# Step 236000, 500s elapsed, -10s remaining
# Step 237000, 505s elapsed, -13s remaining
# Step 238000, 509s elapsed, -15s remaining
# Step 239000, 513s elapsed, -17s remaining
# Step 240000, 517s elapsed, -19s remaining
# Step 241000, 522s elapsed, -21s remaining
# Step 242000, 526s elapsed, -24s remaining
# Step 243000, 530s elapsed, -26s remaining
# Step 244000, 534s elapsed, -28s remaining
# Step 245000, 539s elapsed, -31s remaining
# Step 246000, 543s elapsed, -33s remaining
# Step 247000, 547s elapsed, -35s remaining
# Step 248000, 551s elapsed, -38s remaining
# Step 249000, 555s elapsed, -40s remaining
# Step 250000, 560s elapsed, -42s remaining
# Step 251000, 564s elapsed, -45s remaining
# Step 252000, 568s elapsed, -47s remaining
# Step 253000, 572s elapsed, -50s remaining
# Step 254000, 577s elapsed, -52s remaining
# Step 255000, 581s elapsed, -55s remaining
# Step 256000, 585s elapsed, -57s remaining
# Step 257000, 589s elapsed, -59s remaining
# Step 258000, 594s elapsed, -62s remaining
# Step 259000, 598s elapsed, -64s remaining
# Step 260000, 602s elapsed, -67s remaining
# Step 261000, 606s elapsed, -70s remaining
# Step 262000, 611s elapsed, -72s remaining
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.5         |
# |    ep_rew_mean          | 0.035       |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 4           |
# |    time_elapsed         | 611         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.010048234 |
# |    clip_fraction        | 0.0903      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | -0.433      |
# |    grad_norm            | 0.0931      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.594      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0381     |
# |    value_loss           | 0.00114     |
# -----------------------------------------
# Logging to ./hybrid_ppo_logs_1/PPO_3
# Step 263000, 4s elapsed, 1s remaining
# Step 264000, 8s elapsed, 3s remaining
# Step 265000, 12s elapsed, 4s remaining
# Step 266000, 16s elapsed, 6s remaining
# Step 267000, 21s elapsed, 7s remaining
# Step 268000, 25s elapsed, 9s remaining
# Step 269000, 29s elapsed, 10s remaining
# Step 270000, 33s elapsed, 11s remaining
# Step 271000, 37s elapsed, 13s remaining
# Step 272000, 42s elapsed, 14s remaining
# Step 273000, 46s elapsed, 15s remaining
# Step 274000, 50s elapsed, 16s remaining
# Step 275000, 54s elapsed, 17s remaining
# Step 276000, 59s elapsed, 18s remaining
# Step 277000, 63s elapsed, 19s remaining
# Step 278000, 67s elapsed, 20s remaining
# Step 279000, 71s elapsed, 21s remaining
# Step 280000, 76s elapsed, 22s remaining
# Step 281000, 80s elapsed, 23s remaining
# Step 282000, 84s elapsed, 24s remaining
# Step 283000, 89s elapsed, 25s remaining
# Step 284000, 93s elapsed, 26s remaining
# Step 285000, 97s elapsed, 26s remaining
# Step 286000, 101s elapsed, 27s remaining
# Step 287000, 106s elapsed, 28s remaining
# Step 288000, 110s elapsed, 28s remaining
# Step 289000, 114s elapsed, 29s remaining
# Step 290000, 119s elapsed, 29s remaining
# Step 291000, 123s elapsed, 30s remaining
# Step 292000, 127s elapsed, 30s remaining
# Step 293000, 131s elapsed, 31s remaining
# Step 294000, 136s elapsed, 32s remaining
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.64     |
# |    ep_rew_mean     | 0.0364   |
# | time/              |          |
# |    fps             | 234      |
# |    iterations      | 1        |
# |    time_elapsed    | 139      |
# |    total_timesteps | 294912   |
# | train/             |          |
# |    grad_norm       | 0.103    |
# ---------------------------------
# Step 295000, 150s elapsed, 34s remaining
# Step 296000, 154s elapsed, 34s remaining
# Step 297000, 159s elapsed, 35s remaining
# Step 298000, 163s elapsed, 35s remaining
# Step 299000, 167s elapsed, 35s remaining
# Step 300000, 171s elapsed, 35s remaining
# Step 301000, 175s elapsed, 36s remaining
# Step 302000, 180s elapsed, 36s remaining
# Step 303000, 184s elapsed, 36s remaining
# Step 304000, 188s elapsed, 36s remaining
# Step 305000, 192s elapsed, 36s remaining
# Step 306000, 196s elapsed, 36s remaining
# Step 307000, 201s elapsed, 36s remaining
# Step 308000, 205s elapsed, 36s remaining
# Step 309000, 209s elapsed, 36s remaining
# Step 310000, 214s elapsed, 36s remaining
# Step 311000, 218s elapsed, 36s remaining
# Step 312000, 222s elapsed, 36s remaining
# Step 313000, 227s elapsed, 36s remaining
# Step 314000, 231s elapsed, 35s remaining
# Step 315000, 235s elapsed, 35s remaining
# Step 316000, 243s elapsed, 35s remaining
# Step 317000, 247s elapsed, 35s remaining
# Step 318000, 252s elapsed, 35s remaining
# Step 319000, 256s elapsed, 35s remaining
# Step 320000, 260s elapsed, 34s remaining
# Step 321000, 264s elapsed, 34s remaining
# Step 322000, 269s elapsed, 33s remaining
# Step 323000, 273s elapsed, 33s remaining
# Step 324000, 277s elapsed, 33s remaining
# Step 325000, 281s elapsed, 32s remaining
# Step 326000, 286s elapsed, 32s remaining
# Step 327000, 290s elapsed, 31s remaining
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.71        |
# |    ep_rew_mean          | 0.0371      |
# | time/                   |             |
# |    fps                  | 223         |
# |    iterations           | 2           |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.009823637 |
# |    clip_fraction        | 0.0842      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | -0.0667     |
# |    grad_norm            | 0.164       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.633      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0334     |
# |    value_loss           | 0.000739    |
# -----------------------------------------
# Step 328000, 304s elapsed, 32s remaining
# Step 329000, 308s elapsed, 31s remaining
# Step 330000, 312s elapsed, 30s remaining
# Step 331000, 316s elapsed, 30s remaining
# Step 332000, 321s elapsed, 29s remaining
# Step 333000, 325s elapsed, 28s remaining
# Step 334000, 329s elapsed, 28s remaining
# Step 335000, 334s elapsed, 27s remaining
# Step 336000, 338s elapsed, 26s remaining
# Step 337000, 342s elapsed, 26s remaining
# Step 338000, 347s elapsed, 25s remaining
# Step 339000, 351s elapsed, 24s remaining
# Step 340000, 355s elapsed, 23s remaining
# Step 341000, 359s elapsed, 22s remaining
# Step 342000, 363s elapsed, 21s remaining
# Step 343000, 368s elapsed, 21s remaining
# Step 344000, 372s elapsed, 20s remaining
# Step 345000, 376s elapsed, 19s remaining
# Step 346000, 380s elapsed, 18s remaining
# Step 347000, 385s elapsed, 17s remaining
# Step 348000, 389s elapsed, 16s remaining
# Step 349000, 393s elapsed, 15s remaining
# Step 350000, 397s elapsed, 14s remaining
# Step 351000, 402s elapsed, 13s remaining
# Step 352000, 406s elapsed, 12s remaining
# Step 353000, 410s elapsed, 11s remaining
# Step 354000, 415s elapsed, 10s remaining
# Step 355000, 419s elapsed, 8s remaining
# Step 356000, 423s elapsed, 7s remaining
# Step 357000, 427s elapsed, 6s remaining
# Step 358000, 432s elapsed, 5s remaining
# Step 359000, 436s elapsed, 4s remaining
# Step 360000, 440s elapsed, 3s remaining
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.55        |
# |    ep_rew_mean          | 0.0355      |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 3           |
# |    time_elapsed         | 442         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.009971283 |
# |    clip_fraction        | 0.0889      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.7        |
# |    explained_variance   | 0.0366      |
# |    grad_norm            | 0.164       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.626      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.035      |
# |    value_loss           | 0.000534    |
# -----------------------------------------
# Step 361000, 462s elapsed, 1s remaining
# Step 362000, 468s elapsed, 0s remaining
# Step 363000, 473s elapsed, -1s remaining
# Step 364000, 477s elapsed, -2s remaining
# Step 365000, 481s elapsed, -4s remaining
# Step 366000, 485s elapsed, -5s remaining
# Step 367000, 490s elapsed, -6s remaining
# Step 368000, 494s elapsed, -8s remaining
# Step 369000, 498s elapsed, -9s remaining
# Step 370000, 502s elapsed, -11s remaining
# Step 371000, 507s elapsed, -12s remaining
# Step 372000, 511s elapsed, -14s remaining
# Step 373000, 516s elapsed, -15s remaining
# Step 374000, 521s elapsed, -17s remaining
# Step 375000, 525s elapsed, -18s remaining
# Step 376000, 529s elapsed, -20s remaining
# Step 377000, 534s elapsed, -21s remaining
# Step 378000, 538s elapsed, -23s remaining
# Step 379000, 542s elapsed, -24s remaining
# Step 380000, 547s elapsed, -26s remaining
# Step 381000, 551s elapsed, -27s remaining
# Step 382000, 555s elapsed, -29s remaining
# Step 383000, 560s elapsed, -30s remaining
# Step 384000, 564s elapsed, -32s remaining
# Step 385000, 568s elapsed, -34s remaining
# Step 386000, 572s elapsed, -35s remaining
# Step 387000, 577s elapsed, -37s remaining
# Step 388000, 973s elapsed, -65s remaining
# Step 389000, 978s elapsed, -68s remaining
# Step 390000, 983s elapsed, -70s remaining
# Step 391000, 987s elapsed, -73s remaining
# Step 392000, 991s elapsed, -76s remaining
# Step 393000, 996s elapsed, -78s remaining
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.64        |
# |    ep_rew_mean          | 0.0364      |
# | time/                   |             |
# |    fps                  | 131         |
# |    iterations           | 4           |
# |    time_elapsed         | 996         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.009413198 |
# |    clip_fraction        | 0.077       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.7        |
# |    explained_variance   | 0.102       |
# |    grad_norm            | 0.163       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.63       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0305     |
# |    value_loss           | 0.000599    |
# -----------------------------------------
# Logging to ./hybrid_ppo_logs_1/PPO_3
# Step 394000, 4s elapsed, 1s remaining
# Step 395000, 8s elapsed, 2s remaining
# Step 396000, 13s elapsed, 3s remaining
# Step 397000, 18s elapsed, 4s remaining
# Step 398000, 22s elapsed, 5s remaining
# Step 399000, 26s elapsed, 6s remaining
# Step 400000, 31s elapsed, 7s remaining
# Step 401000, 35s elapsed, 8s remaining
# Step 402000, 39s elapsed, 9s remaining
# Step 403000, 44s elapsed, 10s remaining
# Step 404000, 48s elapsed, 11s remaining
# Step 405000, 53s elapsed, 11s remaining
# Step 406000, 57s elapsed, 12s remaining
# Step 407000, 61s elapsed, 13s remaining
# Step 408000, 66s elapsed, 14s remaining
# Step 409000, 70s elapsed, 14s remaining
# Step 410000, 74s elapsed, 15s remaining
# Step 411000, 79s elapsed, 16s remaining
# Step 412000, 83s elapsed, 16s remaining
# Step 413000, 87s elapsed, 17s remaining
# Step 414000, 92s elapsed, 18s remaining
# Step 415000, 96s elapsed, 18s remaining
# Step 416000, 100s elapsed, 19s remaining
# Step 417000, 104s elapsed, 19s remaining
# Step 418000, 109s elapsed, 20s remaining
# Step 419000, 113s elapsed, 20s remaining
# Step 420000, 117s elapsed, 20s remaining
# Step 421000, 122s elapsed, 21s remaining
# Step 422000, 126s elapsed, 21s remaining
# Step 423000, 130s elapsed, 22s remaining
# Step 424000, 134s elapsed, 22s remaining
# Step 425000, 139s elapsed, 22s remaining
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.59     |
# |    ep_rew_mean     | 0.0359   |
# | time/              |          |
# |    fps             | 229      |
# |    iterations      | 1        |
# |    time_elapsed    | 142      |
# |    total_timesteps | 425984   |
# | train/             |          |
# |    grad_norm       | 0.165    |
# ---------------------------------
# Step 426000, 153s elapsed, 24s remaining
# Step 427000, 158s elapsed, 24s remaining
# Step 428000, 162s elapsed, 25s remaining
# Step 429000, 166s elapsed, 25s remaining
# Step 430000, 171s elapsed, 25s remaining
# Step 431000, 175s elapsed, 25s remaining
# Step 432000, 179s elapsed, 25s remaining
# Step 433000, 183s elapsed, 26s remaining
# Step 434000, 188s elapsed, 26s remaining
# Step 435000, 192s elapsed, 26s remaining
# Step 436000, 197s elapsed, 26s remaining
# Step 437000, 201s elapsed, 26s remaining
# Step 438000, 205s elapsed, 26s remaining
# Step 439000, 210s elapsed, 26s remaining
# Step 440000, 214s elapsed, 26s remaining
# Step 441000, 219s elapsed, 26s remaining
# Step 442000, 223s elapsed, 26s remaining
# Step 443000, 228s elapsed, 26s remaining
# Step 444000, 232s elapsed, 26s remaining
# Step 445000, 236s elapsed, 26s remaining
# Step 446000, 241s elapsed, 25s remaining
# Step 447000, 245s elapsed, 25s remaining
# Step 448000, 250s elapsed, 25s remaining
# Step 449000, 254s elapsed, 25s remaining
# Step 450000, 259s elapsed, 25s remaining
# Step 451000, 263s elapsed, 25s remaining
# Step 452000, 267s elapsed, 24s remaining
# Step 453000, 271s elapsed, 24s remaining
# Step 454000, 276s elapsed, 24s remaining
# Step 455000, 280s elapsed, 24s remaining
# Step 456000, 285s elapsed, 23s remaining
# Step 457000, 289s elapsed, 23s remaining
# Step 458000, 293s elapsed, 23s remaining
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.62        |
# |    ep_rew_mean          | 0.0562      |
# | time/                   |             |
# |    fps                  | 221         |
# |    iterations           | 2           |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.009282902 |
# |    clip_fraction        | 0.0743      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.7        |
# |    explained_variance   | 0.117       |
# |    grad_norm            | 0.0505      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.59       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0255     |
# |    value_loss           | 0.000796    |
# -----------------------------------------
# Step 459000, 307s elapsed, 23s remaining
# Step 460000, 312s elapsed, 23s remaining
# Step 461000, 316s elapsed, 22s remaining
# Step 462000, 321s elapsed, 22s remaining
# Step 463000, 325s elapsed, 21s remaining
# Step 464000, 329s elapsed, 21s remaining
# Step 465000, 333s elapsed, 20s remaining
# Step 466000, 338s elapsed, 20s remaining
# Step 467000, 342s elapsed, 19s remaining
# Step 468000, 346s elapsed, 19s remaining
# Step 469000, 351s elapsed, 18s remaining
# Step 470000, 355s elapsed, 18s remaining
# Step 471000, 359s elapsed, 17s remaining
# Step 472000, 364s elapsed, 16s remaining
# Step 473000, 368s elapsed, 16s remaining
# Step 474000, 372s elapsed, 15s remaining
# Step 475000, 377s elapsed, 14s remaining
# Step 476000, 381s elapsed, 14s remaining
# Step 477000, 386s elapsed, 13s remaining
# Step 478000, 390s elapsed, 12s remaining
# Step 479000, 394s elapsed, 12s remaining
# Step 480000, 398s elapsed, 11s remaining
# Step 481000, 403s elapsed, 10s remaining
# Step 482000, 407s elapsed, 9s remaining
# Step 483000, 411s elapsed, 9s remaining
# Step 484000, 416s elapsed, 8s remaining
# Step 485000, 420s elapsed, 7s remaining
# Step 486000, 424s elapsed, 6s remaining
# Step 487000, 428s elapsed, 5s remaining
# Step 488000, 433s elapsed, 5s remaining
# Step 489000, 437s elapsed, 4s remaining
# Step 490000, 442s elapsed, 3s remaining
# Step 491000, 446s elapsed, 2s remaining
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.63        |
# |    ep_rew_mean          | 0.0363      |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 3           |
# |    time_elapsed         | 448         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.008235231 |
# |    clip_fraction        | 0.0581      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | 0.12        |
# |    grad_norm            | 0.0286      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.563      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0202     |
# |    value_loss           | 0.000898    |
# -----------------------------------------
# Step 492000, 461s elapsed, 1s remaining
# Step 493000, 465s elapsed, 0s remaining
# Step 494000, 469s elapsed, -1s remaining
# Step 495000, 474s elapsed, -2s remaining
# Step 496000, 478s elapsed, -3s remaining
# Step 497000, 482s elapsed, -4s remaining
# Step 498000, 486s elapsed, -5s remaining
# Step 499000, 491s elapsed, -6s remaining
# Step 500000, 495s elapsed, -7s remaining
# Step 501000, 499s elapsed, -8s remaining
# Step 502000, 504s elapsed, -9s remaining
# Step 503000, 508s elapsed, -10s remaining
# Step 504000, 512s elapsed, -11s remaining
# Step 505000, 516s elapsed, -12s remaining
# Step 506000, 521s elapsed, -13s remaining
# Step 507000, 525s elapsed, -14s remaining
# Step 508000, 529s elapsed, -15s remaining
# Step 509000, 533s elapsed, -17s remaining
# Step 510000, 538s elapsed, -18s remaining
# Step 511000, 542s elapsed, -19s remaining
# Step 512000, 546s elapsed, -20s remaining
# Step 513000, 551s elapsed, -21s remaining
# Step 514000, 555s elapsed, -22s remaining
# Step 515000, 559s elapsed, -24s remaining
# Step 516000, 564s elapsed, -25s remaining
# Step 517000, 568s elapsed, -26s remaining
# Step 518000, 572s elapsed, -27s remaining
# Step 519000, 577s elapsed, -29s remaining
# Step 520000, 581s elapsed, -30s remaining
# Step 521000, 585s elapsed, -31s remaining
# Step 522000, 589s elapsed, -32s remaining
# Step 523000, 594s elapsed, -34s remaining
# Step 524000, 598s elapsed, -35s remaining
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.7         |
# |    ep_rew_mean          | 0.037       |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 4           |
# |    time_elapsed         | 599         |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.010547891 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.7        |
# |    explained_variance   | 0.326       |
# |    grad_norm            | 0.171       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.601      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0369     |
# |    value_loss           | 0.000287    |
# -----------------------------------------
# Logging to ./hybrid_ppo_logs_1/PPO_3
# Step 525000, 3s elapsed, 1s remaining
# Step 526000, 7s elapsed, 1s remaining
# Step 527000, 12s elapsed, 2s remaining
# Step 528000, 16s elapsed, 3s remaining
# Step 529000, 20s elapsed, 4s remaining
# Step 530000, 24s elapsed, 4s remaining
# Step 531000, 29s elapsed, 5s remaining
# Step 532000, 33s elapsed, 6s remaining
# Step 533000, 38s elapsed, 6s remaining
# Step 534000, 42s elapsed, 7s remaining
# Step 535000, 46s elapsed, 8s remaining
# Step 536000, 51s elapsed, 8s remaining
# Step 537000, 55s elapsed, 9s remaining
# Step 538000, 60s elapsed, 10s remaining
# Step 539000, 64s elapsed, 10s remaining
# Step 540000, 69s elapsed, 11s remaining
# Step 541000, 73s elapsed, 11s remaining
# Step 542000, 77s elapsed, 12s remaining
# Step 543000, 82s elapsed, 12s remaining
# Step 544000, 86s elapsed, 13s remaining
# Step 545000, 90s elapsed, 13s remaining
# Step 546000, 94s elapsed, 14s remaining
# Step 547000, 99s elapsed, 14s remaining
# Step 548000, 103s elapsed, 14s remaining
# Step 549000, 107s elapsed, 15s remaining
# Step 550000, 112s elapsed, 15s remaining
# Step 551000, 116s elapsed, 15s remaining
# Step 552000, 120s elapsed, 16s remaining
# Step 553000, 124s elapsed, 16s remaining
# Step 554000, 129s elapsed, 16s remaining
# Step 555000, 133s elapsed, 17s remaining
# Step 556000, 138s elapsed, 17s remaining
# Step 557000, 142s elapsed, 17s remaining
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.69     |
# |    ep_rew_mean     | 0.0369   |
# | time/              |          |
# |    fps             | 230      |
# |    iterations      | 1        |
# |    time_elapsed    | 142      |
# |    total_timesteps | 557056   |
# | train/             |          |
# |    grad_norm       | 0.0429   |
# ---------------------------------
# Step 558000, 159s elapsed, 19s remaining
# Step 559000, 164s elapsed, 19s remaining
# Step 560000, 168s elapsed, 19s remaining
# Step 561000, 173s elapsed, 20s remaining
# Step 562000, 178s elapsed, 20s remaining
# Step 563000, 182s elapsed, 20s remaining
# Step 564000, 187s elapsed, 20s remaining
# Step 565000, 192s elapsed, 20s remaining
# Step 566000, 197s elapsed, 20s remaining
# Step 567000, 201s elapsed, 20s remaining
# Step 568000, 206s elapsed, 20s remaining
# Step 569000, 211s elapsed, 20s remaining
# Step 570000, 215s elapsed, 21s remaining
# Step 571000, 220s elapsed, 21s remaining
# Step 572000, 225s elapsed, 21s remaining
# Step 573000, 229s elapsed, 21s remaining
# Step 574000, 234s elapsed, 20s remaining
# Step 575000, 239s elapsed, 20s remaining
# Step 576000, 243s elapsed, 20s remaining
# Step 577000, 248s elapsed, 20s remaining
# Step 578000, 252s elapsed, 20s remaining
# Step 579000, 257s elapsed, 20s remaining
# Step 580000, 262s elapsed, 20s remaining
# Step 581000, 266s elapsed, 20s remaining
# Step 582000, 270s elapsed, 20s remaining
# Step 583000, 275s elapsed, 19s remaining
# Step 584000, 279s elapsed, 19s remaining
# Step 585000, 284s elapsed, 19s remaining
# Step 586000, 289s elapsed, 19s remaining
# Step 587000, 294s elapsed, 19s remaining
# Step 588000, 298s elapsed, 18s remaining
# Step 589000, 303s elapsed, 18s remaining
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.72       |
# |    ep_rew_mean          | 0.0372     |
# | time/                   |            |
# |    fps                  | 213        |
# |    iterations           | 2          |
# |    time_elapsed         | 306        |
# |    total_timesteps      | 589824     |
# | train/                  |            |
# |    approx_kl            | 0.00867023 |
# |    clip_fraction        | 0.0673     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.69      |
# |    explained_variance   | 0.177      |
# |    grad_norm            | 0.178      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.611     |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0229    |
# |    value_loss           | 0.000642   |
# ----------------------------------------
# Step 590000, 320s elapsed, 19s remaining
# Step 591000, 324s elapsed, 18s remaining
# Step 592000, 329s elapsed, 18s remaining
# Step 593000, 333s elapsed, 18s remaining
# Step 594000, 338s elapsed, 17s remaining
# Step 595000, 342s elapsed, 17s remaining
# Step 596000, 346s elapsed, 16s remaining
# Step 597000, 351s elapsed, 16s remaining
# Step 598000, 355s elapsed, 16s remaining
# Step 599000, 359s elapsed, 15s remaining
# Step 600000, 364s elapsed, 15s remaining
# Step 601000, 369s elapsed, 14s remaining
# Step 602000, 374s elapsed, 14s remaining
# Step 603000, 379s elapsed, 13s remaining
# Step 604000, 384s elapsed, 13s remaining
# Step 605000, 388s elapsed, 12s remaining
# Step 606000, 393s elapsed, 12s remaining
# Step 607000, 397s elapsed, 11s remaining
# Step 608000, 402s elapsed, 11s remaining
# Step 609000, 406s elapsed, 10s remaining
# Step 610000, 411s elapsed, 10s remaining
# Step 611000, 415s elapsed, 9s remaining
# Step 612000, 420s elapsed, 8s remaining
# Step 613000, 424s elapsed, 8s remaining
# Step 614000, 429s elapsed, 7s remaining
# Step 615000, 433s elapsed, 7s remaining
# Step 616000, 438s elapsed, 6s remaining
# Step 617000, 442s elapsed, 5s remaining
# Step 618000, 447s elapsed, 5s remaining
# Step 619000, 451s elapsed, 4s remaining
# Step 620000, 456s elapsed, 3s remaining
# Step 621000, 462s elapsed, 2s remaining
# Step 622000, 467s elapsed, 2s remaining
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.55         |
# |    ep_rew_mean          | 0.0355       |
# | time/                   |              |
# |    fps                  | 209          |
# |    iterations           | 3            |
# |    time_elapsed         | 469          |
# |    total_timesteps      | 622592       |
# | train/                  |              |
# |    approx_kl            | 0.0072214524 |
# |    clip_fraction        | 0.0461       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.69        |
# |    explained_variance   | 0.117        |
# |    grad_norm            | 0.0346       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.576       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0153      |
# |    value_loss           | 0.00111      |
# ------------------------------------------
# Step 623000, 482s elapsed, 1s remaining
# Step 624000, 487s elapsed, 0s remaining
# Step 625000, 491s elapsed, -1s remaining
# Step 626000, 496s elapsed, -1s remaining
# Step 627000, 500s elapsed, -2s remaining
# Step 628000, 505s elapsed, -3s remaining
# Step 629000, 509s elapsed, -4s remaining
# Step 630000, 514s elapsed, -5s remaining
# Step 631000, 518s elapsed, -6s remaining
# Step 632000, 522s elapsed, -6s remaining
# Step 633000, 527s elapsed, -7s remaining
# Step 634000, 532s elapsed, -8s remaining
# Step 635000, 537s elapsed, -9s remaining
# Step 636000, 541s elapsed, -10s remaining
# Step 637000, 545s elapsed, -11s remaining
# Step 638000, 550s elapsed, -12s remaining
# Step 639000, 555s elapsed, -13s remaining
# Step 640000, 559s elapsed, -14s remaining
# Step 641000, 564s elapsed, -15s remaining
# Step 642000, 568s elapsed, -16s remaining
# Step 643000, 572s elapsed, -17s remaining
# Step 644000, 577s elapsed, -18s remaining
# Step 645000, 581s elapsed, -19s remaining
# Step 646000, 586s elapsed, -20s remaining
# Step 647000, 590s elapsed, -21s remaining
# Step 648000, 594s elapsed, -22s remaining
# Step 649000, 599s elapsed, -23s remaining
# Step 650000, 603s elapsed, -24s remaining
# Step 651000, 608s elapsed, -25s remaining
# Step 652000, 612s elapsed, -26s remaining
# Step 653000, 617s elapsed, -27s remaining
# Step 654000, 621s elapsed, -28s remaining
# Step 655000, 625s elapsed, -29s remaining
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.58        |
# |    ep_rew_mean          | 0.0358      |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 4           |
# |    time_elapsed         | 626         |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.008600551 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.69       |
# |    explained_variance   | 0.114       |
# |    grad_norm            | 0.195       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.631      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0182     |
# |    value_loss           | 0.001       |
# -----------------------------------------
# Switching to boards: [(3, 13), (5, 3), (8, 4), (6, 24), (7, 13), (1, 1), (11, 18), (10, 27)]
# Logging to ./hybrid_ppo_logs_1/PPO_3
# Step 656000, 3s elapsed, 0s remaining
# Step 657000, 7s elapsed, 1s remaining
# Step 658000, 11s elapsed, 2s remaining
# Step 659000, 16s elapsed, 2s remaining
# Step 660000, 20s elapsed, 3s remaining
# Step 661000, 25s elapsed, 4s remaining
# Step 662000, 29s elapsed, 4s remaining
# Step 663000, 33s elapsed, 5s remaining
# Step 664000, 38s elapsed, 5s remaining
# Step 665000, 42s elapsed, 6s remaining
# Step 666000, 46s elapsed, 6s remaining
# Step 667000, 50s elapsed, 7s remaining
# Step 668000, 54s elapsed, 7s remaining
# Step 669000, 59s elapsed, 8s remaining
# Step 670000, 64s elapsed, 8s remaining
# Step 671000, 68s elapsed, 9s remaining
# Step 672000, 73s elapsed, 9s remaining
# Step 673000, 77s elapsed, 9s remaining
# Step 674000, 82s elapsed, 10s remaining
# Step 675000, 86s elapsed, 10s remaining
# Step 676000, 91s elapsed, 11s remaining
# Step 677000, 95s elapsed, 11s remaining
# Step 678000, 100s elapsed, 11s remaining
# Step 679000, 104s elapsed, 12s remaining
# Step 680000, 108s elapsed, 12s remaining
# Step 681000, 113s elapsed, 12s remaining
# Step 682000, 117s elapsed, 13s remaining
# Step 683000, 122s elapsed, 13s remaining
# Step 684000, 126s elapsed, 13s remaining
# Step 685000, 130s elapsed, 13s remaining
# Step 686000, 135s elapsed, 14s remaining
# Step 687000, 139s elapsed, 14s remaining
# Step 688000, 143s elapsed, 14s remaining
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.68     |
# |    ep_rew_mean     | 0.0368   |
# | time/              |          |
# |    fps             | 228      |
# |    iterations      | 1        |
# |    time_elapsed    | 143      |
# |    total_timesteps | 688128   |
# | train/             |          |
# |    grad_norm       | 0.165    |
# ---------------------------------
# Step 689000, 157s elapsed, 15s remaining
# Step 690000, 162s elapsed, 15s remaining
# Step 691000, 166s elapsed, 15s remaining
# Step 692000, 171s elapsed, 16s remaining
# Step 693000, 175s elapsed, 16s remaining
# Step 694000, 180s elapsed, 16s remaining
# Step 695000, 184s elapsed, 16s remaining
# Step 696000, 188s elapsed, 16s remaining
# Step 697000, 193s elapsed, 16s remaining
# Step 698000, 197s elapsed, 16s remaining
# Step 699000, 201s elapsed, 16s remaining
# Step 700000, 205s elapsed, 16s remaining
# Step 701000, 209s elapsed, 16s remaining
# Step 702000, 214s elapsed, 16s remaining
# Step 703000, 218s elapsed, 16s remaining
# Step 704000, 222s elapsed, 16s remaining
# Step 705000, 227s elapsed, 16s remaining
# Step 706000, 231s elapsed, 16s remaining
# Step 707000, 235s elapsed, 16s remaining
# Step 708000, 240s elapsed, 16s remaining
# Step 709000, 244s elapsed, 16s remaining
# Step 710000, 248s elapsed, 16s remaining
# Step 711000, 253s elapsed, 16s remaining
# Step 712000, 257s elapsed, 16s remaining
# Step 713000, 262s elapsed, 16s remaining
# Step 714000, 266s elapsed, 15s remaining
# Step 715000, 270s elapsed, 15s remaining
# Step 716000, 275s elapsed, 15s remaining
# Step 717000, 279s elapsed, 15s remaining
# Step 718000, 283s elapsed, 15s remaining
# Step 719000, 288s elapsed, 15s remaining
# Step 720000, 292s elapsed, 14s remaining
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.67        |
# |    ep_rew_mean          | 0.0367      |
# | time/                   |             |
# |    fps                  | 221         |
# |    iterations           | 2           |
# |    time_elapsed         | 295         |
# |    total_timesteps      | 720896      |
# | train/                  |             |
# |    approx_kl            | 0.010375483 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.64       |
# |    explained_variance   | 0.268       |
# |    grad_norm            | 0.167       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.599      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0322     |
# |    value_loss           | 0.000391    |
# -----------------------------------------
# Step 721000, 306s elapsed, 15s remaining
# Step 722000, 310s elapsed, 14s remaining
# Step 723000, 315s elapsed, 14s remaining
# Step 724000, 319s elapsed, 14s remaining
# Step 725000, 323s elapsed, 14s remaining
# Step 726000, 327s elapsed, 13s remaining
# Step 727000, 331s elapsed, 13s remaining
# Step 728000, 336s elapsed, 13s remaining
# Step 729000, 340s elapsed, 12s remaining
# Step 730000, 344s elapsed, 12s remaining
# Step 731000, 348s elapsed, 12s remaining
# Step 732000, 353s elapsed, 11s remaining
# Step 733000, 357s elapsed, 11s remaining
# Step 734000, 361s elapsed, 11s remaining
# Step 735000, 366s elapsed, 10s remaining
# Step 736000, 370s elapsed, 10s remaining
# Step 737000, 374s elapsed, 9s remaining
# Step 738000, 378s elapsed, 9s remaining
# Step 739000, 383s elapsed, 8s remaining
# Step 740000, 387s elapsed, 8s remaining
# Step 741000, 391s elapsed, 8s remaining
# Step 742000, 396s elapsed, 7s remaining
# Step 743000, 400s elapsed, 7s remaining
# ...
# |    time_elapsed    | 3299     |
# |    total_timesteps | 1081344  |
# | train/             |          |
# |    grad_norm       | 0.195    |
# ---------------------------------
# Step 1082000, 3313s elapsed, 204s remaining
# Step 1083000, 3317s elapsed, 201s remaining
# Step 1084000, 3321s elapsed, 198s remaining
# Step 1085000, 3325s elapsed, 195s remaining
# Step 1086000, 3329s elapsed, 192s remaining
# Step 1087000, 3334s elapsed, 189s remaining
# Step 1088000, 3338s elapsed, 186s remaining
# Step 1089000, 3342s elapsed, 183s remaining
# Step 1090000, 3346s elapsed, 180s remaining
# Step 1091000, 3350s elapsed, 177s remaining
# Step 1092000, 3354s elapsed, 174s remaining
# Step 1093000, 3359s elapsed, 171s remaining
# Step 1094000, 3363s elapsed, 168s remaining
# Step 1095000, 3367s elapsed, 165s remaining
# Step 1096000, 3372s elapsed, 162s remaining
# Step 1097000, 3376s elapsed, 159s remaining
# Step 1098000, 4322s elapsed, 199s remaining
# Step 1099000, 5245s elapsed, 237s remaining
# Step 1100000, 5264s elapsed, 232s remaining
# Step 1101000, 5270s elapsed, 228s remaining
# Step 1102000, 5275s elapsed, 223s remaining
# Step 1103000, 5279s elapsed, 218s remaining
# Step 1104000, 5283s elapsed, 213s remaining
# Step 1105000, 5288s elapsed, 209s remaining
# Step 1106000, 5292s elapsed, 204s remaining
# Step 1107000, 5296s elapsed, 199s remaining
# Step 1108000, 5300s elapsed, 194s remaining
# Step 1109000, 5305s elapsed, 189s remaining
# Step 1110000, 5313s elapsed, 185s remaining
# Step 1111000, 5317s elapsed, 180s remaining
# Step 1112000, 5321s elapsed, 175s remaining
# Step 1113000, 5325s elapsed, 170s remaining
# Step 1114000, 5330s elapsed, 165s remaining
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.61        |
# |    ep_rew_mean          | 0.0361      |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 2           |
# |    time_elapsed         | 5330        |
# |    total_timesteps      | 1114112     |
# | train/                  |             |
# |    approx_kl            | 0.009836275 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0.195       |
# |    grad_norm            | 0.197       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.598      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0259     |
# |    value_loss           | 0.000629    |
# -----------------------------------------
# Step 1115000, 5344s elapsed, 161s remaining
# Step 1116000, 5348s elapsed, 156s remaining
# Step 1117000, 5352s elapsed, 151s remaining
# Step 1118000, 5356s elapsed, 146s remaining
# Step 1119000, 5361s elapsed, 142s remaining
# Step 1120000, 5365s elapsed, 137s remaining
# Step 1121000, 5369s elapsed, 132s remaining
# Step 1122000, 5373s elapsed, 127s remaining
# Step 1123000, 5377s elapsed, 122s remaining
# Step 1124000, 5382s elapsed, 118s remaining
# Step 1125000, 5386s elapsed, 113s remaining
# Step 1126000, 5390s elapsed, 108s remaining
# Step 1127000, 5394s elapsed, 103s remaining
# Step 1128000, 5399s elapsed, 98s remaining
# Step 1129000, 5403s elapsed, 94s remaining
# Step 1130000, 5407s elapsed, 89s remaining
# Step 1131000, 5411s elapsed, 84s remaining
# Step 1132000, 5415s elapsed, 79s remaining
# Step 1133000, 5419s elapsed, 75s remaining
# Step 1134000, 5424s elapsed, 70s remaining
# Step 1135000, 5428s elapsed, 65s remaining
# Step 1136000, 5432s elapsed, 60s remaining
# Step 1137000, 5436s elapsed, 55s remaining
# Step 1138000, 5440s elapsed, 51s remaining
# Step 1139000, 5444s elapsed, 46s remaining
# Step 1140000, 5449s elapsed, 41s remaining
# Step 1141000, 5453s elapsed, 36s remaining
# Step 1142000, 5457s elapsed, 31s remaining
# Step 1143000, 5461s elapsed, 27s remaining
# Step 1144000, 5466s elapsed, 22s remaining
# Step 1145000, 5470s elapsed, 17s remaining
# Step 1146000, 5474s elapsed, 12s remaining
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.62        |
# |    ep_rew_mean          | 0.0362      |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 3           |
# |    time_elapsed         | 5477        |
# |    total_timesteps      | 1146880     |
# | train/                  |             |
# |    approx_kl            | 0.008695979 |
# |    clip_fraction        | 0.0648      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0.146       |
# |    grad_norm            | 0.191       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.583      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0184     |
# |    value_loss           | 0.000874    |
# -----------------------------------------
# Step 1147000, 5487s elapsed, 8s remaining
# Step 1148000, 5492s elapsed, 3s remaining
# Step 1149000, 5496s elapsed, -2s remaining
# Step 1150000, 5500s elapsed, -7s remaining
# Step 1151000, 5504s elapsed, -12s remaining
# Step 1152000, 5508s elapsed, -16s remaining
# Step 1153000, 5513s elapsed, -21s remaining
# Step 1154000, 5517s elapsed, -26s remaining
# Step 1155000, 5521s elapsed, -31s remaining
# Step 1156000, 5525s elapsed, -35s remaining
# Step 1157000, 5530s elapsed, -40s remaining
# Step 1158000, 5534s elapsed, -45s remaining
# Step 1159000, 5538s elapsed, -50s remaining
# Step 1160000, 5542s elapsed, -55s remaining
# Step 1161000, 5547s elapsed, -59s remaining
# Step 1162000, 5551s elapsed, -64s remaining
# Step 1163000, 5555s elapsed, -69s remaining
# Step 1164000, 5559s elapsed, -74s remaining
# Step 1165000, 5563s elapsed, -78s remaining
# Step 1166000, 5567s elapsed, -83s remaining
# Step 1167000, 5571s elapsed, -88s remaining
# Step 1168000, 5576s elapsed, -93s remaining
# Step 1169000, 5580s elapsed, -97s remaining
# Step 1170000, 5584s elapsed, -102s remaining
# Step 1171000, 5588s elapsed, -107s remaining
# Step 1172000, 5593s elapsed, -112s remaining
# Step 1173000, 5597s elapsed, -117s remaining
# Step 1174000, 5601s elapsed, -121s remaining
# Step 1175000, 5606s elapsed, -126s remaining
# Step 1176000, 5610s elapsed, -131s remaining
# Step 1177000, 5614s elapsed, -136s remaining
# Step 1178000, 5618s elapsed, -140s remaining
# Step 1179000, 5622s elapsed, -145s remaining
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.74        |
# |    ep_rew_mean          | 0.0374      |
# | time/                   |             |
# |    fps                  | 23          |
# |    iterations           | 4           |
# |    time_elapsed         | 5625        |
# |    total_timesteps      | 1179648     |
# | train/                  |             |
# |    approx_kl            | 0.010145442 |
# |    clip_fraction        | 0.0893      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0.303       |
# |    grad_norm            | 0.183       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.587      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.028      |
# |    value_loss           | 0.00038     |
# -----------------------------------------
# Logging to ./hybrid_ppo_logs_1/PPO_3
# Step 1180000, 2s elapsed, 0s remaining
# Step 1181000, 6s elapsed, 1s remaining
# Step 1182000, 10s elapsed, 1s remaining
# Step 1183000, 14s elapsed, 1s remaining
# Step 1184000, 19s elapsed, 2s remaining
# Step 1185000, 23s elapsed, 2s remaining
# Step 1186000, 27s elapsed, 2s remaining
# Step 1187000, 31s elapsed, 2s remaining
# Step 1188000, 36s elapsed, 3s remaining
# Step 1189000, 40s elapsed, 3s remaining
# Step 1190000, 44s elapsed, 3s remaining
# Step 1191000, 48s elapsed, 4s remaining
# Step 1192000, 53s elapsed, 4s remaining
# Step 1193000, 57s elapsed, 4s remaining
# Step 1194000, 61s elapsed, 4s remaining
# Step 1195000, 65s elapsed, 5s remaining
# Step 1196000, 69s elapsed, 5s remaining
# Step 1197000, 73s elapsed, 5s remaining
# Step 1198000, 77s elapsed, 5s remaining
# Step 1199000, 82s elapsed, 5s remaining
# Step 1200000, 86s elapsed, 6s remaining
# Step 1201000, 90s elapsed, 6s remaining
# Step 1202000, 94s elapsed, 6s remaining
# Step 1203000, 98s elapsed, 6s remaining
# Step 1204000, 103s elapsed, 6s remaining
# Step 1205000, 107s elapsed, 7s remaining
# Step 1206000, 111s elapsed, 7s remaining
# Step 1207000, 115s elapsed, 7s remaining
# Step 1208000, 120s elapsed, 7s remaining
# Step 1209000, 124s elapsed, 7s remaining
# Step 1210000, 128s elapsed, 7s remaining
# Step 1211000, 132s elapsed, 7s remaining
# Step 1212000, 136s elapsed, 8s remaining
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.71     |
# |    ep_rew_mean     | 0.0371   |
# | time/              |          |
# |    fps             | 237      |
# |    iterations      | 1        |
# |    time_elapsed    | 137      |
# |    total_timesteps | 1212416  |
# | train/             |          |
# |    grad_norm       | 0.0323   |
# ---------------------------------
# Step 1213000, 150s elapsed, 8s remaining
# Step 1214000, 154s elapsed, 8s remaining
# Step 1215000, 159s elapsed, 8s remaining
# Step 1216000, 163s elapsed, 9s remaining
# Step 1217000, 167s elapsed, 9s remaining
# Step 1218000, 171s elapsed, 9s remaining
# Step 1219000, 175s elapsed, 9s remaining
# Step 1220000, 179s elapsed, 9s remaining
# Step 1221000, 184s elapsed, 9s remaining
# Step 1222000, 188s elapsed, 9s remaining
# Step 1223000, 192s elapsed, 9s remaining
# Step 1224000, 196s elapsed, 9s remaining
# Step 1225000, 200s elapsed, 9s remaining
# Step 1226000, 205s elapsed, 9s remaining
# Step 1227000, 209s elapsed, 9s remaining
# Step 1228000, 213s elapsed, 9s remaining
# Step 1229000, 217s elapsed, 9s remaining
# Step 1230000, 222s elapsed, 9s remaining
# Step 1231000, 226s elapsed, 9s remaining
# Step 1232000, 230s elapsed, 9s remaining
# Step 1233000, 234s elapsed, 9s remaining
# Step 1234000, 239s elapsed, 9s remaining
# Step 1235000, 243s elapsed, 9s remaining
# Step 1236000, 247s elapsed, 9s remaining
# Step 1237000, 251s elapsed, 9s remaining
# Step 1238000, 256s elapsed, 9s remaining
# Step 1239000, 1166s elapsed, 38s remaining
# Step 1240000, 1171s elapsed, 37s remaining
# Step 1241000, 1175s elapsed, 37s remaining
# Step 1242000, 1180s elapsed, 36s remaining
# Step 1243000, 1184s elapsed, 35s remaining
# Step 1244000, 1188s elapsed, 34s remaining
# Step 1245000, 1192s elapsed, 33s remaining
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.7         |
# |    ep_rew_mean          | 0.037       |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 2           |
# |    time_elapsed         | 1192        |
# |    total_timesteps      | 1245184     |
# | train/                  |             |
# |    approx_kl            | 0.009194865 |
# |    clip_fraction        | 0.0792      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0.168       |
# |    grad_norm            | 0.0342      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.548      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0208     |
# |    value_loss           | 0.000755    |
# -----------------------------------------
# Step 1246000, 1206s elapsed, 33s remaining
# Step 1247000, 1210s elapsed, 32s remaining
# Step 1248000, 1513s elapsed, 38s remaining
# Step 1249000, 1517s elapsed, 37s remaining
# Step 1250000, 1521s elapsed, 36s remaining
# Step 1251000, 1525s elapsed, 35s remaining
# Step 1252000, 1530s elapsed, 34s remaining
# Step 1253000, 1534s elapsed, 33s remaining
# Step 1254000, 1538s elapsed, 31s remaining
# Step 1255000, 1542s elapsed, 30s remaining
# Step 1256000, 1546s elapsed, 29s remaining
# Step 1257000, 1550s elapsed, 28s remaining
# Step 1258000, 1555s elapsed, 27s remaining
# Step 1259000, 1857s elapsed, 30s remaining
# Step 1260000, 1861s elapsed, 29s remaining
# Step 1261000, 1865s elapsed, 28s remaining
# Step 1262000, 1870s elapsed, 26s remaining
# Step 1263000, 1874s elapsed, 25s remaining
# Step 1264000, 1878s elapsed, 23s remaining
# Step 1265000, 1882s elapsed, 22s remaining
# Step 1266000, 1886s elapsed, 20s remaining
# Step 1267000, 1891s elapsed, 19s remaining
# Step 1268000, 1895s elapsed, 17s remaining
# Step 1269000, 1899s elapsed, 16s remaining
# Step 1270000, 1903s elapsed, 14s remaining
# Step 1271000, 2881s elapsed, 20s remaining
# Step 1272000, 2886s elapsed, 17s remaining
# Step 1273000, 2890s elapsed, 15s remaining
# Step 1274000, 2894s elapsed, 13s remaining
# Step 1275000, 2898s elapsed, 11s remaining
# Step 1276000, 2902s elapsed, 8s remaining
# Step 1277000, 2907s elapsed, 6s remaining
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.67        |
# |    ep_rew_mean          | 0.0467      |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 3           |
# |    time_elapsed         | 2910        |
# |    total_timesteps      | 1277952     |
# | train/                  |             |
# |    approx_kl            | 0.008482627 |
# |    clip_fraction        | 0.0597      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0.13        |
# |    grad_norm            | 0.0373      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.558      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 0.000993    |
# -----------------------------------------
# Step 1278000, 2920s elapsed, 4s remaining
# Step 1279000, 2924s elapsed, 1s remaining
# Step 1280000, 3855s elapsed, -1s remaining
# Step 1281000, 3860s elapsed, -4s remaining
# Step 1282000, 3864s elapsed, -7s remaining
# Step 1283000, 3868s elapsed, -10s remaining
# Step 1284000, 3872s elapsed, -13s remaining
# Step 1285000, 3876s elapsed, -16s remaining
# Step 1286000, 3881s elapsed, -19s remaining
# Step 1287000, 3885s elapsed, -22s remaining
# Step 1288000, 3889s elapsed, -25s remaining
# Step 1289000, 3893s elapsed, -28s remaining
# Step 1290000, 3898s elapsed, -31s remaining
# Step 1291000, 4812s elapsed, -42s remaining
# Step 1292000, 4816s elapsed, -46s remaining
# Step 1293000, 4820s elapsed, -50s remaining
# Step 1294000, 4824s elapsed, -54s remaining
# Step 1295000, 4829s elapsed, -57s remaining
# Step 1296000, 4833s elapsed, -61s remaining
# Step 1297000, 4837s elapsed, -65s remaining
# Step 1298000, 4841s elapsed, -68s remaining
# Step 1299000, 4845s elapsed, -72s remaining
# Step 1300000, 4849s elapsed, -76s remaining
# Step 1301000, 4854s elapsed, -80s remaining
# Step 1302000, 5806s elapsed, -100s remaining
# Step 1303000, 5810s elapsed, -104s remaining
# Step 1304000, 5814s elapsed, -109s remaining
# Step 1305000, 5818s elapsed, -113s remaining
# Step 1306000, 5822s elapsed, -117s remaining
# Step 1307000, 5827s elapsed, -122s remaining
# Step 1308000, 5831s elapsed, -126s remaining
# Step 1309000, 5835s elapsed, -131s remaining
# Step 1310000, 5839s elapsed, -135s remaining
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.74        |
# |    ep_rew_mean          | 0.0374      |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 4           |
# |    time_elapsed         | 5842        |
# |    total_timesteps      | 1310720     |
# | train/                  |             |
# |    approx_kl            | 0.008586068 |
# |    clip_fraction        | 0.064       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0.132       |
# |    grad_norm            | 0.0346      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.551      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0183     |
# |    value_loss           | 0.000994    |
# -----------------------------------------

# %% [markdown]
# # Evaluation

# %%
from hybrid_env import HybridAPADEnv


def evaluate_agent(model, n_puzzles=50):
    """Evaluate agent on ability to create solvable 5-piece states.

    Returns:
        dict with agent_solvable_rate, random_solvable_rate, mean_solver_time_ms
    """
    agent_solvable = 0
    random_solvable = 0
    solver_times = []

    for _ in range(n_puzzles):
        month = random.randint(1, 12)
        day = random.randint(1, 30)

        # Agent's 5-piece placement
        test_env = HybridAPADEnv(month, day, agent_pieces=5)
        obs, info = test_env.reset()

        for _ in range(5):
            action_masks = info["action_mask"]
            action, _ = model.predict(obs, action_masks=action_masks, deterministic=True)
            obs, reward, terminated, truncated, info = test_env.step(action)

            if terminated or truncated:
                break

        if "solver_time_ms" in info:
            agent_solvable += reward > 0
            solver_times.append(info["solver_time_ms"])

        # Random 5-piece placement
        random_env = HybridAPADEnv(month, day, agent_pieces=5)
        obs, info = random_env.reset()

        for _ in range(5):
            action_masks = info["action_mask"]
            valid_actions = np.where(action_masks)[0]
            if len(valid_actions) == 0:
                break
            action = np.random.choice(valid_actions)
            obs, reward, terminated, truncated, info = random_env.step(action)

            if terminated or truncated:
                break

        if "solver_time_ms" in info:
            random_solvable += reward > 0

    return {
        "agent_solvable_rate": agent_solvable / n_puzzles,
        "random_solvable_rate": random_solvable / n_puzzles,
        "mean_solver_time_ms": np.mean(solver_times) if solver_times else 0,
        "agent_advantage": (agent_solvable - random_solvable) / n_puzzles,
    }


results = evaluate_agent(model, n_puzzles=100)
print(f"Agent solvable rate: {results['agent_solvable_rate']:.1%}")
print(f"Random solvable rate: {results['random_solvable_rate']:.1%}")
print(f"Agent advantage: {results['agent_advantage']:+.1%}")
print(f"Mean solver time: {results['mean_solver_time_ms']:.1f}ms")
